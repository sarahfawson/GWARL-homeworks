# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd
import numpy as np
import requests
import time
import csv
from citipy import citipy

# Import API key
import sys
sys.path.append('../../..')
from api_keys import api_key

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# start api call
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={api_key}&units={units}&q="

# params 
city_data = []
cloudiness_data = []
country_data = []
date_data = []
humidity_data = []
lat_data = []
lon_data = []
max_temp_data = []
wind_speed_data = []

print("Beginning Data Retrieval")
counter = 0

# perform multiple api calls and exception handle
for city in cities:   
    try:
        counter += 1
        if counter % 55 == 0:
            time.sleep(60)

        print("----------------------")
        print("Processing Record " + str(counter) + " | " + city)
        city = city.replace(" ","%20")
        response = requests.get(query_url + city).json()
        
        #api calls
        cloudiness_data.append(response.get("clouds").get("all"))
        country_data.append(response.get("sys").get("country"))
        date_data.append(response.get("dt"))
        humidity_data.append(response.get("main").get("humidity"))
        lat_data.append(response.get("coord").get("lat"))
        lon_data.append(response.get("coord").get("lon"))
        max_temp_data.append(response.get("main").get("temp_max"))
        wind_speed_data.append(response.get("wind").get("speed"))
        city_data.append(response.get("name")) # city is last for better error handling

    except:
        print("City not found. Skipping...")

print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------
# Processing Record 1 | puerto ayora
# ----------------------
# Processing Record 2 | narrabri
# ----------------------
# Processing Record 3 | tukrah
# City not found. Skipping...
# ----------------------
# Processing Record 4 | lere
# ----------------------
# Processing Record 5 | never
# ----------------------
# Processing Record 6 | angoche
# ----------------------
# Processing Record 7 | amderma
# City not found. Skipping...
# ----------------------
# Processing Record 8 | kapaa
# ----------------------
# Processing Record 9 | sechura
# ----------------------
# Processing Record 10 | ilulissat
# ----------------------
# Processing Record 11 | sola
# ----------------------
# Processing Record 12 | bluff
# ----------------------
# Processing Record 13 | albany
# ----------------------
# Processing Record 14 | pangnirtung
# ----------------------
# Processing Record 15 | jamestown
# ----------------------
# Processing Record 16 | warqla
# City not found. Skipping...
# ----------------------
# Processing Record 17 | provideniya
# ----------------------
# Processing Record 18 | lujan
# ----------------------
# Processing Record 19 | taolanaro
# City not found. Skipping...
# ----------------------
# Processing Record 20 | crab hill
# City not found. Skipping...
# ----------------------
# Processing Record 21 | avarua
# ----------------------
# Processing Record 22 | hamilton
# ----------------------
# Processing Record 23 | catabola
# ----------------------
# Processing Record 24 | bengkulu
# City not found. Skipping...
# ----------------------
# Processing Record 25 | new norfolk
# ----------------------
# Processing Record 26 | sao filipe
# ----------------------
# Processing Record 27 | lafiagi
# ----------------------
# Processing Record 28 | hilo
# ----------------------
# Processing Record 29 | saint george
# ----------------------
# Processing Record 30 | busselton
# ----------------------
# Processing Record 31 | lamar
# ----------------------
# Processing Record 32 | fortuna
# ----------------------
# Processing Record 33 | khatanga
# ----------------------
# Processing Record 34 | tabulbah
# City not found. Skipping...
# ----------------------
# Processing Record 35 | dingle
# ----------------------
# Processing Record 36 | parkes
# ----------------------
# Processing Record 37 | byron bay
# ----------------------
# Processing Record 38 | namibe
# ----------------------
# Processing Record 39 | san vicente
# ----------------------
# Processing Record 40 | shitanjing
# ----------------------
# Processing Record 41 | paragominas
# ----------------------
# Processing Record 42 | vardo
# ----------------------
# Processing Record 43 | kaitangata
# ----------------------
# Processing Record 44 | sikasso
# ----------------------
# Processing Record 45 | illoqqortoormiut
# City not found. Skipping...
# ----------------------
# Processing Record 46 | lompoc
# ----------------------
# Processing Record 47 | stephenville
# ----------------------
# Processing Record 48 | mpika
# ----------------------
# Processing Record 49 | mataura
# ----------------------
# Processing Record 50 | ulladulla
# ----------------------
# Processing Record 51 | providencia
# ----------------------
# Processing Record 52 | punta arenas
# ----------------------
# Processing Record 53 | rawson
# ----------------------
# Processing Record 54 | rikitea
# ----------------------
# Processing Record 55 | ushuaia
# ----------------------
# Processing Record 56 | rawannawi
# City not found. Skipping...
# ----------------------
# Processing Record 57 | matara
# ----------------------
# Processing Record 58 | ribeira grande
# ----------------------
# Processing Record 59 | peniche
# ----------------------
# Processing Record 60 | greenfield
# ----------------------
# Processing Record 61 | araouane
# ----------------------
# Processing Record 62 | tapah
# ----------------------
# Processing Record 63 | butaritari
# ----------------------
# Processing Record 64 | torbay
# ----------------------
# Processing Record 65 | college
# ----------------------
# Processing Record 66 | nizhneyansk
# City not found. Skipping...
# ----------------------
# Processing Record 67 | ponta do sol
# ----------------------
# Processing Record 68 | biltine
# ----------------------
# Processing Record 69 | acapulco
# ----------------------
# Processing Record 70 | beringovskiy
# ----------------------
# Processing Record 71 | vestmanna
# ----------------------
# Processing Record 72 | hobart
# ----------------------
# Processing Record 73 | georgetown
# ----------------------
# Processing Record 74 | paita
# ----------------------
# Processing Record 75 | rocky mountain house
# ----------------------
# Processing Record 76 | lagoa
# ----------------------
# Processing Record 77 | arraial do cabo
# ----------------------
# Processing Record 78 | shingu
# ----------------------
# Processing Record 79 | bitung
# ----------------------
# Processing Record 80 | kodiak
# ----------------------
# Processing Record 81 | attawapiskat
# City not found. Skipping...
# ----------------------
# Processing Record 82 | iqaluit
# ----------------------
# Processing Record 83 | barawe
# City not found. Skipping...
# ----------------------
# Processing Record 84 | zabid
# ----------------------
# Processing Record 85 | cururupu
# ----------------------
# Processing Record 86 | wasilla
# ----------------------
# Processing Record 87 | kologriv
# ----------------------
# Processing Record 88 | klaksvik
# ----------------------
# Processing Record 89 | viligili
# City not found. Skipping...
# ----------------------
# Processing Record 90 | port elizabeth
# ----------------------
# Processing Record 91 | mys shmidta
# City not found. Skipping...
# ----------------------
# Processing Record 92 | gafurov
# City not found. Skipping...
# ----------------------
# Processing Record 93 | emmauss
# City not found. Skipping...
# ----------------------
# Processing Record 94 | tasiilaq
# ----------------------
# Processing Record 95 | clyde river
# ----------------------
# Processing Record 96 | emba
# ----------------------
# Processing Record 97 | dzhebariki-khaya
# ----------------------
# Processing Record 98 | lewisburg
# ----------------------
# Processing Record 99 | chaplynka
# ----------------------
# Processing Record 100 | padang
# ----------------------
# Processing Record 101 | east london
# ----------------------
# Processing Record 102 | praia
# ----------------------
# Processing Record 103 | meulaboh
# ----------------------
# Processing Record 104 | eureka
# ----------------------
# Processing Record 105 | san cristobal
# ----------------------
# Processing Record 106 | atuona
# ----------------------
# Processing Record 107 | dobrinka
# ----------------------
# Processing Record 108 | kathu
# ----------------------
# Processing Record 109 | alta floresta
# ----------------------
# Processing Record 110 | saint augustine
# ----------------------
# Processing Record 111 | luderitz
# ----------------------
# Processing Record 112 | richards bay
# ----------------------
# Processing Record 113 | fairbanks
# ----------------------
# Processing Record 114 | cape town
# ----------------------
# Processing Record 115 | airai
# ----------------------
# Processing Record 116 | salalah
# ----------------------
# Processing Record 117 | union city
# ----------------------
# Processing Record 118 | ancud
# ----------------------
# Processing Record 119 | mutsamudu
# City not found. Skipping...
# ----------------------
# Processing Record 120 | brae
# ----------------------
# Processing Record 121 | belushya guba
# City not found. Skipping...
# ----------------------
# Processing Record 122 | rantauprapat
# ----------------------
# Processing Record 123 | portland
# ----------------------
# Processing Record 124 | sao joao da barra
# ----------------------
# Processing Record 125 | carnarvon
# ----------------------
# Processing Record 126 | bilma
# ----------------------
# Processing Record 127 | cessnock
# ----------------------
# Processing Record 128 | maha sarakham
# ----------------------
# Processing Record 129 | ribeirao branco
# ----------------------
# Processing Record 130 | faya
# ----------------------
# Processing Record 131 | hami
# ----------------------
# Processing Record 132 | hithadhoo
# ----------------------
# Processing Record 133 | mount gambier
# ----------------------
# Processing Record 134 | nagua
# ----------------------
# Processing Record 135 | korhogo
# ----------------------
# Processing Record 136 | mercedes
# ----------------------
# Processing Record 137 | yarmouth
# ----------------------
# Processing Record 138 | nishihara
# ----------------------
# Processing Record 139 | evans
# ----------------------
# Processing Record 140 | kutum
# ----------------------
# Processing Record 141 | mar del plata
# ----------------------
# Processing Record 142 | tuatapere
# ----------------------
# Processing Record 143 | vaitupu
# City not found. Skipping...
# ----------------------
# Processing Record 144 | ahipara
# ----------------------
# Processing Record 145 | vaini
# ----------------------
# Processing Record 146 | barrow
# ----------------------
# Processing Record 147 | hermanus
# ----------------------
# Processing Record 148 | saint-pierre
# ----------------------
# Processing Record 149 | kitimat
# ----------------------
# Processing Record 150 | sorgun
# ----------------------
# Processing Record 151 | castro
# ----------------------
# Processing Record 152 | monrovia
# ----------------------
# Processing Record 153 | chuy
# ----------------------
# Processing Record 154 | khonuu
# City not found. Skipping...
# ----------------------
# Processing Record 155 | upernavik
# ----------------------
# Processing Record 156 | henties bay
# ----------------------
# Processing Record 157 | whitehorse
# ----------------------
# Processing Record 158 | san patricio
# ----------------------
# Processing Record 159 | hobyo
# ----------------------
# Processing Record 160 | yulara
# ----------------------
# Processing Record 161 | katha
# City not found. Skipping...
# ----------------------
# Processing Record 162 | zavidovici
# ----------------------
# Processing Record 163 | turukhansk
# ----------------------
# Processing Record 164 | baykit
# ----------------------
# Processing Record 165 | faanui
# ----------------------
# Processing Record 166 | voi
# ----------------------
# Processing Record 167 | iguape
# ----------------------
# Processing Record 168 | cidreira
# ----------------------
# Processing Record 169 | banepa
# ----------------------
# Processing Record 170 | el balyana
# City not found. Skipping...
# ----------------------
# Processing Record 171 | lata
# ----------------------
# Processing Record 172 | dikson
# ----------------------
# Processing Record 173 | cabo san lucas
# ----------------------
# Processing Record 174 | morant bay
# ----------------------
# Processing Record 175 | omboue
# ----------------------
# Processing Record 176 | xuddur
# ----------------------
# Processing Record 177 | saskylakh
# ----------------------
# Processing Record 178 | innisfail
# ----------------------
# Processing Record 179 | bethel
# ----------------------
# Processing Record 180 | bereda
# ----------------------
# Processing Record 181 | prudentopolis
# ----------------------
# Processing Record 182 | kapit
# ----------------------
# Processing Record 183 | ixtapa
# ----------------------
# Processing Record 184 | yellowknife
# ----------------------
# Processing Record 185 | chokurdakh
# ----------------------
# Processing Record 186 | buraydah
# ----------------------
# Processing Record 187 | namatanai
# ----------------------
# Processing Record 188 | saint-philippe
# ----------------------
# Processing Record 189 | khipro
# ----------------------
# Processing Record 190 | bredasdorp
# ----------------------
# Processing Record 191 | kegayli
# City not found. Skipping...
# ----------------------
# Processing Record 192 | rio claro
# ----------------------
# Processing Record 193 | port blair
# ----------------------
# Processing Record 194 | freeport
# ----------------------
# Processing Record 195 | port hueneme
# ----------------------
# Processing Record 196 | tsihombe
# City not found. Skipping...
# ----------------------
# Processing Record 197 | savannah bight
# ----------------------
# Processing Record 198 | sao miguel do araguaia
# ----------------------
# Processing Record 199 | hofn
# ----------------------
# Processing Record 200 | timra
# ----------------------
# Processing Record 201 | ust-omchug
# ----------------------
# Processing Record 202 | constitucion
# ----------------------
# Processing Record 203 | lebu
# ----------------------
# Processing Record 204 | nurobod
# ----------------------
# Processing Record 205 | ugoofaaru
# ----------------------
# Processing Record 206 | sioux lookout
# ----------------------
# Processing Record 207 | cherskiy
# ----------------------
# Processing Record 208 | yerbogachen
# ----------------------
# Processing Record 209 | khandbari
# ----------------------
# Processing Record 210 | chicama
# ----------------------
# Processing Record 211 | kloulklubed
# ----------------------
# Processing Record 212 | severo-kurilsk
# ----------------------
# Processing Record 213 | kaeo
# ----------------------
# Processing Record 214 | chaadayevka
# ----------------------
# Processing Record 215 | barentsburg
# City not found. Skipping...
# ----------------------
# Processing Record 216 | taganak
# ----------------------
# Processing Record 217 | izhma
# ----------------------
# Processing Record 218 | sentyabrskiy
# City not found. Skipping...
# ----------------------
# Processing Record 219 | codrington
# ----------------------
# Processing Record 220 | hit
# ----------------------
# Processing Record 221 | dolgoderevenskoye
# ----------------------
# Processing Record 222 | chaozhou
# ----------------------
# Processing Record 223 | vologda
# ----------------------
# Processing Record 224 | badin
# ----------------------
# Processing Record 225 | oistins
# ----------------------
# Processing Record 226 | saldanha
# ----------------------
# Processing Record 227 | komsomolskiy
# ----------------------
# Processing Record 228 | nikolskoye
# ----------------------
# Processing Record 229 | garoua boulai
# ----------------------
# Processing Record 230 | mokhotlong
# ----------------------
# Processing Record 231 | kidal
# ----------------------
# Processing Record 232 | karakendzha
# City not found. Skipping...
# ----------------------
# Processing Record 233 | aflu
# City not found. Skipping...
# ----------------------
# Processing Record 234 | victoria
# ----------------------
# Processing Record 235 | berlevag
# ----------------------
# Processing Record 236 | atikokan
# ----------------------
# Processing Record 237 | hokitika
# ----------------------
# Processing Record 238 | kibala
# ----------------------
# Processing Record 239 | shu
# ----------------------
# Processing Record 240 | abu samrah
# ----------------------
# Processing Record 241 | soller
# ----------------------
# Processing Record 242 | qaanaaq
# ----------------------
# Processing Record 243 | souillac
# ----------------------
# Processing Record 244 | skjervoy
# ----------------------
# Processing Record 245 | huarmey
# ----------------------
# Processing Record 246 | the pas
# ----------------------
# Processing Record 247 | ambatondrazaka
# ----------------------
# Processing Record 248 | grand river south east
# City not found. Skipping...
# ----------------------
# Processing Record 249 | longyearbyen
# ----------------------
# Processing Record 250 | sitka
# ----------------------
# Processing Record 251 | yeniseysk
# ----------------------
# Processing Record 252 | saint-georges
# ----------------------
# Processing Record 253 | megion
# ----------------------
# Processing Record 254 | mezen
# ----------------------
# Processing Record 255 | cuamba
# ----------------------
# Processing Record 256 | whitianga
# ----------------------
# Processing Record 257 | la ronge
# ----------------------
# Processing Record 258 | yar-sale
# ----------------------
# Processing Record 259 | bati
# ----------------------
# Processing Record 260 | noumea
# ----------------------
# Processing Record 261 | mandla
# ----------------------
# Processing Record 262 | carutapera
# ----------------------
# Processing Record 263 | tutoia
# ----------------------
# Processing Record 264 | macas
# ----------------------
# Processing Record 265 | weyburn
# ----------------------
# Processing Record 266 | aklavik
# ----------------------
# Processing Record 267 | sinnamary
# ----------------------
# Processing Record 268 | tongchuan
# ----------------------
# Processing Record 269 | santa cruz de la palma
# ----------------------
# Processing Record 270 | urumqi
# City not found. Skipping...
# ----------------------
# Processing Record 271 | tuktoyaktuk
# ----------------------
# Processing Record 272 | ust-maya
# ----------------------
# Processing Record 273 | adrar
# ----------------------
# Processing Record 274 | makurdi
# ----------------------
# Processing Record 275 | mahebourg
# ----------------------
# Processing Record 276 | thompson
# ----------------------
# Processing Record 277 | westpunt
# City not found. Skipping...
# ----------------------
# Processing Record 278 | kavieng
# ----------------------
# Processing Record 279 | ouesso
# ----------------------
# Processing Record 280 | singkawang
# City not found. Skipping...
# ----------------------
# Processing Record 281 | cayenne
# ----------------------
# Processing Record 282 | nueva guinea
# ----------------------
# Processing Record 283 | donghai
# ----------------------
# Processing Record 284 | sal rei
# ----------------------
# Processing Record 285 | bargal
# City not found. Skipping...
# ----------------------
# Processing Record 286 | lanivtsi
# ----------------------
# Processing Record 287 | toulepleu
# City not found. Skipping...
# ----------------------
# Processing Record 288 | maputo
# ----------------------
# Processing Record 289 | mehamn
# ----------------------
# Processing Record 290 | touros
# ----------------------
# Processing Record 291 | kismayo
# City not found. Skipping...
# ----------------------
# Processing Record 292 | zyryanka
# ----------------------
# Processing Record 293 | casalmaggiore
# ----------------------
# Processing Record 294 | hoquiam
# ----------------------
# Processing Record 295 | leh
# ----------------------
# Processing Record 296 | miyako
# ----------------------
# Processing Record 297 | okhotsk
# ----------------------
# Processing Record 298 | guerrero negro
# ----------------------
# Processing Record 299 | methoni
# ----------------------
# Processing Record 300 | adamovka
# ----------------------
# Processing Record 301 | nanortalik
# ----------------------
# Processing Record 302 | husavik
# ----------------------
# Processing Record 303 | isangel
# ----------------------
# Processing Record 304 | cap malheureux
# ----------------------
# Processing Record 305 | nizhniy ingash
# ----------------------
# Processing Record 306 | maxixe
# ----------------------
# Processing Record 307 | pokhara
# ----------------------
# Processing Record 308 | port alfred
# ----------------------
# Processing Record 309 | ust-kuyga
# ----------------------
# Processing Record 310 | anadyr
# ----------------------
# Processing Record 311 | tiksi
# ----------------------
# Processing Record 312 | quatre cocos
# ----------------------
# Processing Record 313 | taunggyi
# ----------------------
# Processing Record 314 | halalo
# City not found. Skipping...
# ----------------------
# Processing Record 315 | belyy yar
# ----------------------
# Processing Record 316 | krasnoselkup
# City not found. Skipping...
# ----------------------
# Processing Record 317 | honningsvag
# ----------------------
# Processing Record 318 | puerto escondido
# ----------------------
# Processing Record 319 | afanasyevo
# City not found. Skipping...
# ----------------------
# Processing Record 320 | naze
# ----------------------
# Processing Record 321 | arkhara
# ----------------------
# Processing Record 322 | yanan
# City not found. Skipping...
# ----------------------
# Processing Record 323 | kruisfontein
# ----------------------
# Processing Record 324 | te anau
# ----------------------
# Processing Record 325 | minot
# ----------------------
# Processing Record 326 | rudsar
# ----------------------
# Processing Record 327 | sept-iles
# ----------------------
# Processing Record 328 | rosetta
# ----------------------
# Processing Record 329 | banda aceh
# ----------------------
# Processing Record 330 | salinopolis
# ----------------------
# Processing Record 331 | buala
# ----------------------
# Processing Record 332 | baghdad
# ----------------------
# Processing Record 333 | ormara
# ----------------------
# Processing Record 334 | tessalit
# ----------------------
# Processing Record 335 | trinidad
# ----------------------
# Processing Record 336 | raudeberg
# ----------------------
# Processing Record 337 | tambacounda
# ----------------------
# Processing Record 338 | kedrovyy
# ----------------------
# Processing Record 339 | soligalich
# ----------------------
# Processing Record 340 | alyangula
# ----------------------
# Processing Record 341 | inhambane
# ----------------------
# Processing Record 342 | la paz
# ----------------------
# Processing Record 343 | talcahuano
# ----------------------
# Processing Record 344 | santa cruz
# ----------------------
# Processing Record 345 | yeppoon
# ----------------------
# Processing Record 346 | marolambo
# ----------------------
# Processing Record 347 | kyrylivka
# ----------------------
# Processing Record 348 | samusu
# City not found. Skipping...
# ----------------------
# Processing Record 349 | cordenons
# ----------------------
# Processing Record 350 | pedra azul
# ----------------------
# Processing Record 351 | leningradskiy
# ----------------------
# Processing Record 352 | porto novo
# ----------------------
# Processing Record 353 | tokonou
# ----------------------
# Processing Record 354 | ishigaki
# ----------------------
# Processing Record 355 | port-gentil
# ----------------------
# Processing Record 356 | abbeville
# ----------------------
# Processing Record 357 | wilmington
# ----------------------
# Processing Record 358 | abu jubayhah
# City not found. Skipping...
# ----------------------
# Processing Record 359 | praia da vitoria
# ----------------------
# Processing Record 360 | hihifo
# City not found. Skipping...
# ----------------------
# Processing Record 361 | varna
# ----------------------
# Processing Record 362 | yen bai
# ----------------------
# Processing Record 363 | dakar
# ----------------------
# Processing Record 364 | caravelas
# ----------------------
# Processing Record 365 | aldine
# ----------------------
# Processing Record 366 | koindu
# ----------------------
# Processing Record 367 | bulgan
# ----------------------
# Processing Record 368 | lavrentiya
# ----------------------
# Processing Record 369 | varkkallai
# ----------------------
# Processing Record 370 | meyungs
# City not found. Skipping...
# ----------------------
# Processing Record 371 | stromness
# ----------------------
# Processing Record 372 | walvis bay
# ----------------------
# Processing Record 373 | leshukonskoye
# ----------------------
# Processing Record 374 | paraiso
# ----------------------
# Processing Record 375 | kyren
# ----------------------
# Processing Record 376 | filingue
# ----------------------
# Processing Record 377 | laguna
# ----------------------
# Processing Record 378 | talnakh
# ----------------------
# Processing Record 379 | qandala
# ----------------------
# Processing Record 380 | cabra
# ----------------------
# Processing Record 381 | maturin
# ----------------------
# Processing Record 382 | kayerkan
# ----------------------
# Processing Record 383 | great bend
# ----------------------
# Processing Record 384 | vila franca do campo
# ----------------------
# Processing Record 385 | norman wells
# ----------------------
# Processing Record 386 | wattegama
# ----------------------
# Processing Record 387 | green river
# ----------------------
# Processing Record 388 | stornoway
# City not found. Skipping...
# ----------------------
# Processing Record 389 | luanda
# ----------------------
# Processing Record 390 | clarksburg
# ----------------------
# Processing Record 391 | tezu
# ----------------------
# Processing Record 392 | abapo
# ----------------------
# Processing Record 393 | bur gabo
# City not found. Skipping...
# ----------------------
# Processing Record 394 | tura
# ----------------------
# Processing Record 395 | marystown
# ----------------------
# Processing Record 396 | minbu
# ----------------------
# Processing Record 397 | severnyy
# City not found. Skipping...
# ----------------------
# Processing Record 398 | arawa
# ----------------------
# Processing Record 399 | kaihua
# ----------------------
# Processing Record 400 | marsa matruh
# ----------------------
# Processing Record 401 | egvekinot
# ----------------------
# Processing Record 402 | nadym
# ----------------------
# Processing Record 403 | tacoronte
# ----------------------
# Processing Record 404 | chartres
# ----------------------
# Processing Record 405 | sao raimundo das mangabeiras
# ----------------------
# Processing Record 406 | muborak
# ----------------------
# Processing Record 407 | coihaique
# ----------------------
# Processing Record 408 | inirida
# ----------------------
# Processing Record 409 | karkaralinsk
# City not found. Skipping...
# ----------------------
# Processing Record 410 | arlit
# ----------------------
# Processing Record 411 | narsaq
# ----------------------
# Processing Record 412 | donauworth
# ----------------------
# Processing Record 413 | goderich
# ----------------------
# Processing Record 414 | pundaguitan
# ----------------------
# Processing Record 415 | kralendijk
# ----------------------
# Processing Record 416 | mount vernon
# ----------------------
# Processing Record 417 | miramar
# ----------------------
# Processing Record 418 | waipawa
# ----------------------
# Processing Record 419 | barcelona
# ----------------------
# Processing Record 420 | krasnyy chikoy
# ----------------------
# Processing Record 421 | nouadhibou
# ----------------------
# Processing Record 422 | poum
# ----------------------
# Processing Record 423 | pakokku
# ----------------------
# Processing Record 424 | farmington
# ----------------------
# Processing Record 425 | pacific grove
# ----------------------
# Processing Record 426 | tonantins
# ----------------------
# Processing Record 427 | sabya
# ----------------------
# Processing Record 428 | kalabo
# ----------------------
# Processing Record 429 | bambous virieux
# ----------------------
# Processing Record 430 | la romana
# ----------------------
# Processing Record 431 | vestmannaeyjar
# ----------------------
# Processing Record 432 | gambela
# ----------------------
# Processing Record 433 | hualmay
# ----------------------
# Processing Record 434 | fare
# ----------------------
# Processing Record 435 | saint anthony
# ----------------------
# Processing Record 436 | alice springs
# ----------------------
# Processing Record 437 | west bay
# ----------------------
# Processing Record 438 | tiarei
# ----------------------
# Processing Record 439 | mayor pablo lagerenza
# ----------------------
# Processing Record 440 | zhengjiatun
# ----------------------
# Processing Record 441 | mildura
# ----------------------
# Processing Record 442 | dunedin
# ----------------------
# Processing Record 443 | port hardy
# ----------------------
# Processing Record 444 | sindor
# ----------------------
# Processing Record 445 | itarema
# ----------------------
# Processing Record 446 | diffa
# ----------------------
# Processing Record 447 | caxias do sul
# ----------------------
# Processing Record 448 | mecca
# ----------------------
# Processing Record 449 | merauke
# ----------------------
# Processing Record 450 | manaia
# ----------------------
# Processing Record 451 | thai nguyen
# ----------------------
# Processing Record 452 | bandarbeyla
# ----------------------
# Processing Record 453 | leticia
# ----------------------
# Processing Record 454 | broken hill
# ----------------------
# Processing Record 455 | khani
# ----------------------
# Processing Record 456 | chabahar
# ----------------------
# Processing Record 457 | atar
# ----------------------
# Processing Record 458 | champua
# ----------------------
# Processing Record 459 | rungata
# City not found. Skipping...
# ----------------------
# Processing Record 460 | necochea
# ----------------------
# Processing Record 461 | coffs harbour
# ----------------------
# Processing Record 462 | qaqortoq
# ----------------------
# Processing Record 463 | nabire
# ----------------------
# Processing Record 464 | khokhryaki
# ----------------------
# Processing Record 465 | plavsk
# ----------------------
# Processing Record 466 | boguchany
# ----------------------
# Processing Record 467 | kholtoson
# ----------------------
# Processing Record 468 | olafsvik
# City not found. Skipping...
# ----------------------
# Processing Record 469 | hay river
# ----------------------
# Processing Record 470 | viransehir
# ----------------------
# Processing Record 471 | san luis
# ----------------------
# Processing Record 472 | valparaiso
# ----------------------
# Processing Record 473 | kokoda
# ----------------------
# Processing Record 474 | yalta
# ----------------------
# Processing Record 475 | kursenai
# ----------------------
# Processing Record 476 | sur
# ----------------------
# Processing Record 477 | kupang
# ----------------------
# Processing Record 478 | abalak
# ----------------------
# Processing Record 479 | melbu
# ----------------------
# Processing Record 480 | lorengau
# ----------------------
# Processing Record 481 | geraldton
# ----------------------
# Processing Record 482 | north platte
# ----------------------
# Processing Record 483 | shimoda
# ----------------------
# Processing Record 484 | khudumelapye
# ----------------------
# Processing Record 485 | chipinge
# ----------------------
# Processing Record 486 | khor
# ----------------------
# Processing Record 487 | wollongong
# ----------------------
# Processing Record 488 | pangai
# ----------------------
# Processing Record 489 | bosaso
# ----------------------
# Processing Record 490 | tiznit
# ----------------------
# Processing Record 491 | shubarkuduk
# ----------------------
# Processing Record 492 | fonte boa
# ----------------------
# Processing Record 493 | andros town
# ----------------------
# Processing Record 494 | kota belud
# ----------------------
# Processing Record 495 | aketi
# ----------------------
# Processing Record 496 | oriximina
# ----------------------
# Processing Record 497 | minab
# ----------------------
# Processing Record 498 | hambantota
# ----------------------
# Processing Record 499 | pueblo
# ----------------------
# Processing Record 500 | nizwa
# ----------------------
# Processing Record 501 | hasaki
# ----------------------
# Processing Record 502 | gravelbourg
# ----------------------
# Processing Record 503 | skiros
# City not found. Skipping...
# ----------------------
# Processing Record 504 | vidalia
# ----------------------
# Processing Record 505 | kuche
# City not found. Skipping...
# ----------------------
# Processing Record 506 | taoudenni
# ----------------------
# Processing Record 507 | vostok
# ----------------------
# Processing Record 508 | kulhudhuffushi
# ----------------------
# Processing Record 509 | tyukalinsk
# ----------------------
# Processing Record 510 | soyo
# ----------------------
# Processing Record 511 | toliary
# City not found. Skipping...
# ----------------------
# Processing Record 512 | jujuy
# City not found. Skipping...
# ----------------------
# Processing Record 513 | jizan
# ----------------------
# Processing Record 514 | havelock
# ----------------------
# Processing Record 515 | pevek
# ----------------------
# Processing Record 516 | palamos
# ----------------------
# Processing Record 517 | napoleon
# ----------------------
# Processing Record 518 | kahului
# ----------------------
# Processing Record 519 | akdepe
# ----------------------
# Processing Record 520 | nioro
# ----------------------
# Processing Record 521 | vitim
# ----------------------
# Processing Record 522 | avera
# ----------------------
# Processing Record 523 | ambodifototra
# City not found. Skipping...
# ----------------------
# Processing Record 524 | khunti
# ----------------------
# Processing Record 525 | pirapemas
# ----------------------
# Processing Record 526 | itoman
# ----------------------
# Processing Record 527 | bathsheba
# ----------------------
# Processing Record 528 | novyy urgal
# ----------------------
# Processing Record 529 | pitimbu
# ----------------------
# Processing Record 530 | pisco
# ----------------------
# Processing Record 531 | bonavista
# ----------------------
# Processing Record 532 | ekhabi
# ----------------------
# Processing Record 533 | den helder
# ----------------------
# Processing Record 534 | dudinka
# ----------------------
# Processing Record 535 | urbana
# ----------------------
# Processing Record 536 | muravlenko
# ----------------------
# Processing Record 537 | rauma
# ----------------------
# Processing Record 538 | saryshagan
# City not found. Skipping...
# ----------------------
# Processing Record 539 | chimbarongo
# ----------------------
# Processing Record 540 | challans
# ----------------------
# Processing Record 541 | agirish
# ----------------------
# Processing Record 542 | charlestown
# ----------------------
# Processing Record 543 | batagay-alyta
# ----------------------
# Processing Record 544 | siocon
# ----------------------
# Processing Record 545 | mandera
# ----------------------
# Processing Record 546 | cacador
# ----------------------
# Processing Record 547 | nanyang
# ----------------------
# Processing Record 548 | pop
# ----------------------
# Processing Record 549 | margate
# ----------------------
# Processing Record 550 | zachagansk
# City not found. Skipping...
# ----------------------
# Processing Record 551 | san ignacio
# ----------------------
# Processing Record 552 | chahal
# ----------------------
# Processing Record 553 | rantoul
# ----------------------
# Processing Record 554 | tando jam
# ----------------------
# Processing Record 555 | ostrovnoy
# ----------------------
# Processing Record 556 | lolua
# City not found. Skipping...
# ----------------------
# Processing Record 557 | almaznyy
# ----------------------
# Processing Record 558 | vrangel
# ----------------------
# Processing Record 559 | lengshuijiang
# ----------------------
# Processing Record 560 | solnechnyy
# ----------------------
# Processing Record 561 | nguiu
# City not found. Skipping...
# ----------------------
# Processing Record 562 | zaidpur
# ----------------------
# Processing Record 563 | itupiranga
# ----------------------
# Processing Record 564 | beruwala
# ----------------------
# Processing Record 565 | mitsamiouli
# ----------------------
# Processing Record 566 | lashio
# ----------------------
# Processing Record 567 | umm lajj
# ----------------------
# Processing Record 568 | keflavik
# ----------------------
# Processing Record 569 | kalmunai
# ----------------------
# Processing Record 570 | pochutla
# ----------------------
# Processing Record 571 | muisne
# ----------------------
# Processing Record 572 | olinda
# ----------------------
# Processing Record 573 | turinsk
# ----------------------
# Processing Record 574 | pekan
# ----------------------
# Processing Record 575 | andevoranto
# City not found. Skipping...
# ----------------------
# Processing Record 576 | zmievka
# City not found. Skipping...
# ----------------------
# Processing Record 577 | uglich
# ----------------------
# Processing Record 578 | sar-e pul
# ----------------------
# Processing Record 579 | mocuba
# ----------------------
# Processing Record 580 | saleaula
# City not found. Skipping...
# ----------------------
# Processing Record 581 | baoding
# ----------------------
# Processing Record 582 | san juan
# ----------------------
# Processing Record 583 | muros
# ----------------------
# Processing Record 584 | esperance
# ----------------------
# Processing Record 585 | nantucket
# ----------------------
# Processing Record 586 | malartic
# ----------------------
# Processing Record 587 | buchanan
# ----------------------
# Processing Record 588 | moron
# ----------------------
# Processing Record 589 | mayo
# ----------------------
# Processing Record 590 | general roca
# ----------------------
# Processing Record 591 | zaysan
# ----------------------
# Processing Record 592 | tarudant
# City not found. Skipping...
# ----------------------
# Processing Record 593 | nerchinskiy zavod
# ----------------------
# Processing Record 594 | udachnyy
# ----------------------
# Processing Record 595 | zavodouspenskoye
# ----------------------
# Processing Record 596 | sumbawa
# City not found. Skipping...
# ----------------------
# Processing Record 597 | san quintin
# ----------------------
# Processing Record 598 | grindavik
# ----------------------
# Processing Record 599 | putyatino
# ----------------------
# Processing Record 600 | port hedland
# ----------------------
# Processing Record 601 | alipur duar
# City not found. Skipping...
# ----------------------
# Processing Record 602 | kiruna
# ----------------------
# Processing Record 603 | karlshamn
# ----------------------
# Processing Record 604 | jiwani
# ----------------------
# Processing Record 605 | broome
# ----------------------
# Processing Record 606 | satitoa
# City not found. Skipping...
# ----------------------
# Processing Record 607 | tignere
# ----------------------
# Processing Record 608 | nakatsu
# ----------------------
# Processing Record 609 | dubbo
# ----------------------
# Processing Record 610 | palmer
# ----------------------
# Processing Record 611 | daru
# ----------------------
# Processing Record 612 | karaul
# City not found. Skipping...
# ----------------------
# Processing Record 613 | saint-joseph
# ----------------------
# Processing Record 614 | maceio
# ----------------------
# Processing Record 615 | riyadh
# ----------------------
# Processing Record 616 | the valley
# ----------------------
# Processing Record 617 | ajdabiya
# ----------------------
# Processing Record 618 | zhanatas
# City not found. Skipping...
# ----------------------
# Processing Record 619 | belaya gora
# ----------------------
# Processing Record 620 | san jeronimo
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame

# %%
len(city_data)
# Out:
# 553

# %%
# this is the method if I'm not importing data from CSV, but using the lists to compile json data instead
weather_data = {"City" : city_data,
                "Cloudiness": cloudiness_data,
                "Country": country_data,
                "Date": date_data,
                "Humidity": humidity_data,
                "Lat": lat_data,
                "Lng": lon_data,
                "Max Temp": max_temp_data,
                "Wind Speed": wind_speed_data,
                }

weather_data = pd.DataFrame(weather_data)
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  Puerto Ayora          20      EC  1548716400        70  -0.74  -90.35
# 1      Narrabri          24      AU  1548716400        39 -30.33  149.78
# 2          Lere           8      TD  1548719345        32   9.66   14.23
# 3         Never          68      RU  1548719345        84  53.98  124.16
# 4       Angoche          68      MZ  1548719345       100 -16.23   39.91
#
#    Max Temp  Wind Speed
# 0     84.20       13.87
# 1     84.20       18.34
# 2     69.57        8.75
# 3     -6.75        2.59
# 4     81.23       12.33

# %%
# write weather data to a csv
weather_data.to_csv("Output/weather_data.csv")

# %%
weather_data = pd.read_csv("Output/weather_data.csv")
weather_data.head()
# Out:
#    Unnamed: 0          City  Cloudiness Country        Date  Humidity    Lat  \
# 0           0  Puerto Ayora          20      EC  1548716400        70  -0.74
# 1           1      Narrabri          24      AU  1548716400        39 -30.33
# 2           2          Lere           8      TD  1548719345        32   9.66
# 3           3         Never          68      RU  1548719345        84  53.98
# 4           4       Angoche          68      MZ  1548719345       100 -16.23
#
#       Lng  Max Temp  Wind Speed
# 0  -90.35     84.20       13.87
# 1  149.78     84.20       18.34
# 2   14.23     69.57        8.75
# 3  124.16     -6.75        2.59
# 4   39.91     81.23       12.33

# %%
# find weather values for your random list of cities
# random_df = np.random(weather_data)
# random_data.head()

# %% [markdown]
# ### Plotting the Data -- Please beware that I am experimenting with color

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#format date for plot titles
# date_stamp = str(weather_data.iloc[0,3])
# date_stamp = datetime.datetime.fromtimestamp(int(date_stamp)).strftime('%m-%d-%Y')
import datetime
date = datetime.datetime.now().date()
# date = date.astype(str)
print(date)
# Out:
# 2019-01-28

# %%
# Build a scatter plot for each data type
x = weather_data["Lat"]
y = weather_data["Max Temp"]
xy = range(100)
z = xy
colors = cm.rainbow(np.linspace(0, 1, len(x)))
sc = plt.scatter(x, y, vmin=0, vmax=100, color=colors)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature ")# + date)
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save fig
# plt.savefig("Output/CityLat_vs_Max_Temp.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], c='hotpink')
plt.title("City Latitude vs. Humidity " )#+ str(date)
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save fig
plt.savefig("Output/CityLat_vs_Humidity.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], c="m")
plt.title("City Latitude vs. Cloudiness ")# + date)
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save fig
plt.savefig("Output/CityLat_vs_Cloudiness.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], c="mcb")
plt.title("City Latitude vs. Wind Speed ")# + date)
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save fig
plt.savefig("Output/CityLat_vs_Wind_Speed.png")

plt.show()
